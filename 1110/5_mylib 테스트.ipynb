# %%
from mylib import langchain_tool_weather as ask

# %%
ai_response = ask.ask_weather('서울시 구로구 날씨 알려줘')
# Out:
# 2025-11-10 14:38:48,244 - INFO -
# ============================================================
# 2025-11-10 14:38:48,245 - INFO - 🔵 사용자 질문: 서울시 구로구 날씨 알려줘
# 2025-11-10 14:38:48,246 - INFO - ============================================================
# 2025-11-10 14:38:48,982 - INFO - 날씨 에이전트 설정 완료
# 2025-11-10 14:38:48,983 - INFO - 메시지 초기화 완료
# 2025-11-10 14:38:49,882 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-10 14:38:49,931 - INFO - 응답 받음 - tool_calls: 1개
# 2025-11-10 14:38:49,936 - INFO - 도구 호출 발견: 1개
# 2025-11-10 14:38:49,937 - INFO - 도구 실행: get_coordinates
# 2025-11-10 14:38:49,938 - INFO -   - ID: call_69VMPhCPGZZNxAnCABgQmUpA
# 2025-11-10 14:38:49,940 - INFO -   - Args: {'location': '서울시 구로구'}
# 2025-11-10 14:38:51,043 - INFO - 서울시 구로구의 위도: 37.4951999, 경도: 126.8877000
# 2025-11-10 14:38:51,046 - INFO - ✅도구 실행 결과: 37.4951999,126.8877000...
# 2025-11-10 14:38:51,047 - INFO - 🟢 messages:SystemMessage
# 	HumanMessage
# 	AIMessage
# 	ToolMessage
# 2025-11-10 14:38:51,048 - INFO - ============================================================
# 2025-11-10 14:38:52,024 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-10 14:38:52,059 - INFO - 응답 받음 - tool_calls: 1개
# 2025-11-10 14:38:52,062 - INFO - 도구 호출 발견: 1개
# 2025-11-10 14:38:52,067 - INFO - 도구 실행: get_weather_info
# 2025-11-10 14:38:52,071 - INFO -   - ID: call_qmwIcGWkFvXsjrjKAEmityjg
# 2025-11-10 14:38:52,074 - INFO -   - Args: {'lat_lon': '37.4951999,126.8877000'}
# 2025-11-10 14:38:52,302 - INFO - 날씨 정보 조회 성공: Kwangmyŏng
# 2025-11-10 14:38:52,304 - INFO - ✅도구 실행 결과: 날씨: 맑음
# 기온(°C): 10.98°C
# 체감온도(°C): 8.76°C
# 습도(%): 24%
# 지역: Kwangmyŏng...
# 2025-11-10 14:38:52,306 - INFO - 🟢 messages:SystemMessage
# 	HumanMessage
# 	AIMessage
# 	ToolMessage
# 	AIMessage
# 	ToolMessage
# 2025-11-10 14:38:52,307 - INFO - ============================================================
# 2025-11-10 14:38:54,304 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %%
ai_response = ask.ask_weather(user_question='AI Agents 설명해줘')
print(f'💬AI : {ai_response}')
# Out:
# 2025-11-10 14:40:48,112 - INFO -
# ============================================================
# 2025-11-10 14:40:48,113 - INFO - 🔵 사용자 질문: AI Agents 설명해줘
# 2025-11-10 14:40:48,114 - INFO - ============================================================
# 2025-11-10 14:40:48,120 - INFO - 날씨 에이전트 설정 완료
# 2025-11-10 14:40:48,121 - INFO - 메시지 초기화 완료
# 2025-11-10 14:40:51,761 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 💬AI : AI Agents는 인공지능 시스템에서 자율적으로 특정 작업이나 목표를 수행하는 주체를 의미해요. 쉽게 말해, AI 에이전트는 주어진 환경에서 입력(정보)을 받고, 그것을 바탕으로 적절한 행동(결과)를 결정해서 실행하는 역할을 합니다.
#
# 주요 특징을 간단히 설명드리자면:
# 1. **자율성(Autonomy)**: AI 에이전트는 인간의 개입 없이 스스로 판단하고 행동할 수 있어요.
# 2. **환경 인식**: 주변 환경을 센서나 데이터 등을 통해 인식하고 상황을 이해합니다.
# 3. **목표 지향성**: 특정 목표나 임무를 수행하기 위해 행동합니다.
# 4. **적응성**: 환경 변화에 맞춰 학습하고 적응할 수 있어요.
#
# 예를 들어, 자율주행 자동차, 챗봇, 로봇, 게임 속 캐릭터 등이 모두 AI 에이전트의 한 형태라고 볼 수 있습니다.
#
# 더 궁금한 점 있으면 알려주세요! 🤖✨

# %%
ai_response = ask.ask_weather(user_question='서울과 도쿄 날씨 비교해줘')
print(f'💬AI : {ai_response}')
# Out:
# 2025-11-10 14:41:44,612 - INFO -
# ============================================================
# 2025-11-10 14:41:44,612 - INFO - 🔵 사용자 질문: 서울과 도쿄 날씨 비교해줘
# 2025-11-10 14:41:44,613 - INFO - ============================================================
# 2025-11-10 14:41:44,620 - INFO - 날씨 에이전트 설정 완료
# 2025-11-10 14:41:44,621 - INFO - 메시지 초기화 완료
# 2025-11-10 14:41:45,794 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-10 14:41:45,814 - INFO - 응답 받음 - tool_calls: 2개
# 2025-11-10 14:41:45,817 - INFO - 도구 호출 발견: 2개
# 2025-11-10 14:41:45,821 - INFO - 도구 실행: get_coordinates
# 2025-11-10 14:41:45,823 - INFO -   - ID: call_n33oTHz0dNFdwmsXiC44UkU6
# 2025-11-10 14:41:45,825 - INFO -   - Args: {'location': '서울'}
# 2025-11-10 14:41:46,883 - INFO - 서울의 위도: 37.5666791, 경도: 126.9782914
# 2025-11-10 14:41:46,891 - INFO - ✅도구 실행 결과: 37.5666791,126.9782914...
# 2025-11-10 14:41:46,894 - INFO - 도구 실행: get_coordinates
# 2025-11-10 14:41:46,897 - INFO -   - ID: call_64U8HmdTIvuGamxueGXxTFsc
# 2025-11-10 14:41:46,899 - INFO -   - Args: {'location': '도쿄'}
# 2025-11-10 14:41:47,883 - INFO - 도쿄의 위도: 35.6812546, 경도: 139.7667060
# 2025-11-10 14:41:47,892 - INFO - ✅도구 실행 결과: 35.6812546,139.7667060...
# 2025-11-10 14:41:47,895 - INFO - 🟢 messages:SystemMessage
# 	HumanMessage
# 	AIMessage
# 	ToolMessage
# 	ToolMessage
# 2025-11-10 14:41:47,898 - INFO - ============================================================
# 2025-11-10 14:41:50,027 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-10 14:41:50,038 - INFO - 응답 받음 - tool_calls: 2개
# 2025-11-10 14:41:50,040 - INFO - 도구 호출 발견: 2개
# 2025-11-10 14:41:50,044 - INFO - 도구 실행: get_weather_info
# 2025-11-10 14:41:50,046 - INFO -   - ID: call_s9WqofhV2JbQNeajo8UVhIcD
# 2025-11-10 14:41:50,049 - INFO -   - Args: {'lat_lon': '37.5666791,126.9782914'}
# 2025-11-10 14:41:50,264 - INFO - 날씨 정보 조회 성공: Seoul
# 2025-11-10 14:41:50,267 - INFO - ✅도구 실행 결과: 날씨: 맑음
# 기온(°C): 10.76°C
# 체감온도(°C): 8.52°C
# 습도(%): 24%
# 지역: Seoul...
# 2025-11-10 14:41:50,271 - INFO - 도구 실행: get_weather_info
# 2025-11-10 14:41:50,273 - INFO -   - ID: call_mZsK5LqdscgwVTVWrOHWzcD6
# 2025-11-10 14:41:50,275 - INFO -   - Args: {'lat_lon': '35.6812546,139.7667060'}
# 2025-11-10 14:41:50,472 - INFO - 날씨 정보 조회 성공: Marunouchi
# 2025-11-10 14:41:50,475 - INFO - ✅도구 실행 결과: 날씨: 실 비
# 기온(°C): 18.45°C
# 체감온도(°C): 17.42°C
# 습도(%): 41%
# 지역: Marunouchi...
# 2025-11-10 14:41:50,478 - INFO - 🟢 messages:SystemMessage
# 	HumanMessage
# 	AIMessage
# 	ToolMessage
# 	ToolMessage
# 	AIMessage
# 	ToolMessage
# 	ToolMessage
# 2025-11-10 14:41:50,480 - INFO - ============================================================
# 2025-11-10 14:41:53,612 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 💬AI : 서울과 도쿄의 현재 날씨를 알려드릴게요! 🌤️
#
# - 서울
#   - 날씨: 맑음
#   - 기온: 10.76°C
#   - 체감 온도: 8.52°C
#   - 습도: 24%
#
# - 도쿄
#   - 날씨: 실비
#   - 기온: 18.45°C
#   - 체감 온도: 17.42°C
#   - 습도: 41%
#
# 도쿄가 서울보다 기온도 높고 체감 온도도 더 따뜻하네요. 서울은 맑지만 도쿄는 약간 비가 오는 날씨입니다. 필요하시면 더 상세한 정보도 알려드릴게요! ☀️🌧️
