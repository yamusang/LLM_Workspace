# %%
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv()
client = OpenAI()

# %%
question = input("사용자 요청 메시지")
response = client.chat.completions.create(
    model='gpt-4.1-mini',
    messages=[
        # AI 가 할일
        {"role":"system","content":"You are a helpful assistant.using locale language."},
        # 사용자 요청
        {"role":"user","content":question}
    ],
)
#chat.completions
print(f'💬AI: {response.choices[0].message.content}')
# Out:
# 💬AI: 죄송하지만 현재 시간을 확인할 수 없습니다. 사용 중인 기기나 시계를 참고해 주세요.

# %%
# 실시간 데이터는 LLM 의 학습 내용이 아닙니다.
# ㄴ 함수 호출 또는 tools 사용해서 답변을 할 수 있는 기능이 있습니다.

# 시간 구하기 함수
from datetime import datetime

def get_current_time():
    now = datetime.now().strftime('%H:%M:%S')
    print(f'🔄log get_current_time: {now} ')
    return now
get_current_time()

# 날짜 구하기 함수 : 예정  '%Y-%m-%d'
def get_current_date():
    now = datetime.now().strftime('%Y-%m-%d')
    print(f'🔄log get_current_date: {now} ')
    return now

# gpt 가 사용할 함수 목록을 정의
myfunctions = [
    {
        "name": "get_current_time",
        "description": "현재 시간 출력합니다. 포맷 HH:MM:SS 입니다."
    },
    {
        "name": "get_current_date",
        "description": "현재 날짜 출력합니다. 포맷은 YYYY-MM-DD  입니다."
    }
]
# Out:
# 🔄log get_current_time: 12:04:13

# %%
question = '오늘 날짜를 알려줘' #'현재 시간을 알려줘'
response = client.chat.completions.create(
    model='gpt-4.1-mini',
    messages=[
        {"role":"system","content":"You are a helpful assistant.using locale language."},
        {"role":"user","content":question}
    ],
    functions=myfunctions,
)
print(f'🔄log response : {response.model_dump_json(indent=2)}')
# Out:
# 🔄log response : {
#   "id": "chatcmpl-CYkaFq5dsQOmCSesCfvin2AYBakoK",
#   "choices": [
#     {
#       "finish_reason": "function_call",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": null,
#         "refusal": null,
#         "role": "assistant",
#         "annotations": [],
#         "audio": null,
#         "function_call": {
#           "arguments": "{}",
#           "name": "get_current_date"
#         },
#         "tool_calls": null
#       }
#     }
#   ],
#   "created": 1762398255,
#   "model": "gpt-4.1-mini-2025-04-14",
#   "object": "chat.completion",
#   "service_tier": "default",
#   "system_fingerprint": "fp_4c2851f862",
#   "usage": {
#     "completion_tokens": 11,
#     "prompt_tokens": 86,
#     "total_tokens": 97,
#     "completion_tokens_details": {
#       "accepted_prediction_tokens": 0,
#       "audio_tokens": 0,
#       "reasoning_tokens": 0,
#       "rejected_prediction_tokens": 0
#     },
#     "prompt_tokens_details": {
#       "audio_tokens": 0,
#       "cached_tokens": 0
#     }
#   }
# }

# %%
# 함수 호출을 하고 답변을 만드는 추가적인 요청이 필요합니다.
import json
# fn_name = response.choices[0].message.function_call
# ↪ FunctionCall(arguments='{}', name='get_current_time')
fn_name = getattr(response.choices[0].message.function_call,'name',None)
print(f'🔄log fn_name: {fn_name}')
if fn_name:
    func_response = globals()[fn_name]() # 문자열로 된 함수를 호출하는 방법
    followup_response = client.chat.completions.create(
        model='gpt-4.1-mini',
        messages=[
        {"role":"system","content":"You are a helpful assistant.using locale language."},
        {"role":"user",
         "content":f'{fn_name} 함수를 실행한 결과 {func_response} 이용하여 최종 응답 만들어줘.'}
        ],
        functions=myfunctions
    )
    print(followup_response.model_dump_json(indent=2))
    # 함수 실행한 두번째 요청 응답
    result = followup_response.choices[0].message.content
else:
    # 첫번째 요청 응답
    result = response.choices[0].message.content    

print(f'💬AI : {result}')
# Out:
# 🔄log fn_name: get_current_date
# 🔄log get_current_date: 2025-11-06
# {
#   "id": "chatcmpl-CYkaNHwh3YaG0Nj3dKUXCjzDyJoGV",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": "오늘 날짜는 2025년 11월 6일입니다. 도움이 필요하시면 언제든지 말씀해 주세요.",
#         "refusal": null,
#         "role": "assistant",
#         "annotations": [],
#         "audio": null,
#         "function_call": null,
#         "tool_calls": null
#       }
#     }
#   ],
#   "created": 1762398263,
#   "model": "gpt-4.1-mini-2025-04-14",
#   "object": "chat.completion",
#   "service_tier": "default",
#   "system_fingerprint": "fp_4c2851f862",
#   "usage": {
#     "completion_tokens": 27,
#     "prompt_tokens": 105,
#     "total_tokens": 132,
#     "completion_tokens_details": {
#       "accepted_prediction_tokens": 0,
#       "audio_tokens": 0,
#       "reasoning_tokens": 0,
#       "rejected_prediction_tokens": 0
#     },
#     "prompt_tokens_details": {
#       "audio_tokens": 0,
#       "cached_tokens": 0
#     }
#   }
# }
# 💬AI : 오늘 날짜는 2025년 11월 6일입니다. 도움이 필요하시면 언제든지 말씀해 주세요.
