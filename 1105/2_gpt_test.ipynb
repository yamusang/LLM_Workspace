# %%
from dotenv import load_dotenv

# .env 파일에서 OPENAI_API_KEY 이름의 key 값을 가져옵니다.
# -> OpenAI() 객체 생성할 때 사용합니다.
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()

# 모델 : gpt-4.1-mini
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        # 상담사 역할 정의
        {
            "role": "system",
            "content": (
                "당신은 전문 심리상담사입니다. "
                "따뜻하고 공감적인 태도로 대화하며, "
                "사용자의 감정을 존중하고 안전한 분위기를 조성하세요. "
                "직접적인 진단이나 치료 지시는 하지 말고, "
                "대화를 통해 사용자가 스스로 생각을 정리할 수 있도록 돕습니다."
            ) + "그리고 , 다른 질문 또는 심리상담과 상관없는 내용은 '모릅니다.' 로 반드시 답변하기."
        },
        # 내담자(사용자) 메시지
        {
            "role": "user",
            "content": (
                "요즘 일이 너무 많아서 스트레스를 많이 받고 있어요. "
                "밤에도 잠을 잘 못 자고, 계속 불안한 기분이 듭니다."
            )
        }
    ],
    temperature=0.7,  
    # 출력의 창의성과 무작위성을 조절하는 파라미터.(0~1  :사용하는 단어 일반적~창의적)
    max_tokens=300
)
print(response.model_dump_json(indent=2))
# print(response.choices[0].message["content"])
# Out:
# {
#   "id": "chatcmpl-CYiIRkCUXGxd1zsevzY0qseIbareu",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": "많은 일로 인해 스트레스를 받고 계시고, 그로 인해 잠도 제대로 못 자고 불안함까지 느끼신다니 정말 힘드실 것 같아요. 이렇게 힘든 상황 속에서 스스로를 돌보는 게 쉽지 않을 텐데, 지금 어떤 생각들이 가장 크게 마음을 불편하게 하는지 이야기해주실 수 있을까요? 함께 차근차근 이야기를 나누며 어떻게 조금이나마 마음이 편안해질 수 있을지 고민해봐요.",
#         "refusal": null,
#         "role": "assistant",
#         "annotations": [],
#         "audio": null,
#         "function_call": null,
#         "tool_calls": null
#       }
#     }
#   ],
#   "created": 1762389463,
#   "model": "gpt-4.1-mini-2025-04-14",
#   "object": "chat.completion",
#   "service_tier": "default",
#   "system_fingerprint": "fp_4c2851f862",
#   "usage": {
#     "completion_tokens": 108,
#     "prompt_tokens": 139,
#     "total_tokens": 247,
#     "completion_tokens_details": {
#       "accepted_prediction_tokens": 0,
#       "audio_tokens": 0,
#       "reasoning_tokens": 0,
#       "rejected_prediction_tokens": 0
#     },
#     "prompt_tokens_details": {
#       "audio_tokens": 0,
#       "cached_tokens": 0
#     }
#   }
# }

# %%
print(f'💬 AI : {response.choices[0].message.content}')
# Out:
# 💬 AI : 그렇게 많이 바쁘고 힘든 상황 속에서 잠도 제대로 못 자고 불안함까지 느끼신다니 정말 많이 지치셨겠어요. 지금 느끼시는 불안과 잠 부족이 일상에 어떤 영향을 주고 있는지, 혹시 더 이야기해주실 수 있을까요? 함께 이야기하면서 조금이라도 마음이 편해질 수 있으면 좋겠습니다.

# %%
# 참고 : 응답 객체의 key , 구조가 gpt-4과 비교하면 변경되었습니다.
# 모델 : gpt-5-nano
response = client.responses.create(
    model="gpt-5-nano",
    input="Write a one-sentence bedtime story about a unicorn."
)
print(response.model_dump_json(indent=2))
print(f'💬AI :{response.output_text}')
# Out:
# {
#   "id": "resp_02f73af07d74cdc000690ae8b643ac819095047274b0f7642c",
#   "created_at": 1762322614.0,
#   "error": null,
#   "incomplete_details": null,
#   "instructions": null,
#   "metadata": {},
#   "model": "gpt-5-nano-2025-08-07",
#   "object": "response",
#   "output": [
#     {
#       "id": "rs_02f73af07d74cdc000690ae8b750708190a18ef25f2a1ab00b",
#       "summary": [],
#       "type": "reasoning",
#       "content": null,
#       "encrypted_content": null,
#       "status": null
#     },
#     {
#       "id": "msg_02f73af07d74cdc000690ae8baac788190bf630504cf463e73",
#       "content": [
#         {
#           "annotations": [],
#           "text": "Under the silver moon, a gentle unicorn curled in a mossy meadow and drifted off to dreamland, where stars hummed lullabies.",
#           "type": "output_text",
#           "logprobs": []
#         }
#       ],
#       "role": "assistant",
#       "status": "completed",
#       "type": "message"
#     }
#   ],
#   "parallel_tool_calls": true,
#   "temperature": 1.0,
#   "tool_choice": "auto",
#   "tools": [],
#   "top_p": 1.0,
#   "background": false,
#   "conversation": null,
#   "max_output_tokens": null,
#   "max_tool_calls": null,
#   "previous_response_id": null,
#   "prompt": null,
#   "prompt_cache_key": null,
#   "reasoning": {
#     "effort": "medium",
#     "generate_summary": null,
#     "summary": null
#   },
#   "safety_identifier": null,
#   "service_tier": "default",
#   "status": "completed",
#   "text": {
#     "format": {
#       "type": "text"
#     },
#     "verbosity": "medium"
#   },
#   "top_logprobs": 0,
#   "truncation": "disabled",
#   "usage": {
#     "input_tokens": 17,
#     "input_tokens_details": {
#       "cached_tokens": 0
#     },
#     "output_tokens": 483,
#     "output_tokens_details": {
#       "reasoning_tokens": 448
#     },
#     "total_tokens": 500
#   },
#   "user": null,
#   "billing": {
#     "payer": "developer"
#   },
#   "prompt_cache_retention": null,
#   "store": true
# }
# 💬AI :Under the silver moon, a gentle unicorn curled in a mossy meadow and drifted off to dreamland, where stars hummed lullabies.
