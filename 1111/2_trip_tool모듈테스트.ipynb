# %%
from mylib import trip_tool as tt

# %%
#user_input = '2025년 12월 서울에서 열리는 축제 알려줘'
user_input = '방금 무슨 얘기 했지?'
ai_result = tt.run_agent(user_input)
print(ai_result)
# Out:
# ...
# 👤 사용자: 방금 무슨 얘기 했지?
# ...
# 2025-11-11 14:05:45,156 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...
#
# 방금은 따로 대화가 없었어요. 무엇을 도와드릴까요?

# %%
ai_response = tt.get_current_weather.invoke("대한민국 수원시 권선구")
print(ai_response)
# Out:
# 2025-11-11 14:05:45,194 - INFO - Step 1: '대한민국 수원시 권선구'의 좌표 조회 중...
# 2025-11-11 14:05:46,180 - INFO - ✅ 좌표 조회 성공: 대한민국 수원시 권선구 → 위도=37.2567361, 경도=126.9719715
# 2025-11-11 14:05:46,182 - INFO - Step 2: 날씨 정보 조회 중...
# 2025-11-11 14:05:46,402 - INFO - ✅ 날씨 정보 조회 성공: Seryui-dong
# 장소: Seryui-dong (KR)
# ─────────────────────
# 현재 기온: 14.9°C
# 체감 기온: 13.52°C
# 기온 범위: 13.96°C ~ 15.84°C
# 습도: 41%
# 기압: 1022 hPa
# 바람: 0m/s (0°)
# 날씨: 맑음 (Clear)
# 구름: 0%
# 가시거리: 10000m

# %%
user_input = '내가 뭐뭐 물어봤지?'
ai_result = tt.run_history_agent(user_input,"abc")
print(ai_result)
# Out:
# ...
# 👤 사용자: 내가 뭐뭐 물어봤지?
# ...
# 2025-11-11 14:05:47,786 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# 🤖 어시스턴트:
# ...
